# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
PATH = '/content/drive/MyDrive/Univerui/0 MAGISTRAS/tiriamasis/'

classes = PATH + 'data/clean_data_wo_outliers.csv'
LaBSE_UMAP = PATH + 'FeatureSelection/UMAP/labse_umap_embeddings.csv'
W2V_PCA = PATH + 'FeatureSelection/PCA/w2v_pca_embeddings.csv'

output_path = PATH + 'master_experiment_results/'

# %%
# %%capture
# !pip install optuna

# %%
import pandas as pd
import numpy as np

from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score, normalized_mutual_info_score
from sklearn.metrics import mutual_info_score, adjusted_rand_score

from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import MeanShift
from sklearn.cluster import Birch

from sklearn.manifold import TSNE
from scipy.cluster.hierarchy import dendrogram, linkage

import pickle
import optuna

import matplotlib.pyplot as plt
import seaborn as sns

# %%
labse_df = pd.read_csv(LaBSE_UMAP).to_numpy()
w2v_df = pd.read_csv(W2V_PCA).to_numpy()

df = pd.read_csv(classes)
df['Nace2'] = df['Nace2'].astype(int)
df['gr_4digits'] = df['gr_4digits'].astype(int)

# %%
y_true = df['gr_stat_letter']
res_df = df[['imones_kodas','gr_stat_letter']]

# %%
res_df.head()
# Out:
#    imones_kodas gr_stat_letter
# 0     140891278              G
# 1     133852410              J
# 2     304224333              P
# 3     303425493              M
# 4     304869540              M

# %% [markdown]
# # Parameter Search

# %%
N_CLUSTERS = df['gr_stat_letter'].nunique()

# %%
def objective_kmeans(trial):
    params = {
        'n_init': trial.suggest_int('n_init', 5, 20),
        'max_iter': trial.suggest_int('max_iter', 100, 1000),
        'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
        'algorithm': trial.suggest_categorical('algorithm', ['elkan', 'lloyd'])
    }

    model = KMeans(n_clusters=N_CLUSTERS, **params).fit(labse_df)
    score = silhouette_score(labse_df, model.labels_)
    return score

def objective_gmm(trial):
    params = {
        'covariance_type': trial.suggest_categorical('covariance_type', ['full', 'tied', 'diag', 'spherical']),
        'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
        'reg_covar': trial.suggest_loguniform('reg_covar', 1e-6, 1e-2),
        'init_params': trial.suggest_categorical('init_params', ['kmeans', 'random', 'random_from_data', 'k-means++'])
    }

    model = GaussianMixture(n_components=N_CLUSTERS, **params).fit(labse_df)
    labels = model.predict(labse_df)
    score = silhouette_score(labse_df, labels)
    return score

def objective_agglomerative(trial):
    params = {
        'metric': trial.suggest_categorical('metric', ['euclidean', 'manhattan', 'cosine']),
        'linkage': trial.suggest_categorical('linkage', ['complete', 'average', 'single']),
    }

    model = AgglomerativeClustering(n_clusters=N_CLUSTERS, **params).fit(labse_df)
    score = silhouette_score(labse_df, model.labels_)
    return score

def objective_meanshift(trial):
    params = {
        'bandwidth': trial.suggest_float('bandwidth', 0.1, 5.0),
        'bin_seeding': trial.suggest_categorical('bin_seeding', [True, False]),
        'min_bin_freq': trial.suggest_int('min_bin_freq', 1, 10),
        'max_iter': trial.suggest_int('max_iter', 100, 1000)
    }

    model = MeanShift(**params).fit(w2v_df)
    labels = model.labels_
    if len(np.unique(labels)) < 2:
        return -1

    score = silhouette_score(w2v_df, labels)
    return score

def objective_meanshift_2(trial):
    params = {
        'bandwidth': trial.suggest_float('bandwidth', 2.1, 2.8),
        'bin_seeding': trial.suggest_categorical('bin_seeding', [False, False]),
        'min_bin_freq': trial.suggest_int('min_bin_freq', 1, 10),
        'max_iter': trial.suggest_int('max_iter', 200, 400)
    }

    model = MeanShift(**params).fit(w2v_df)
    labels = model.labels_
    if len(np.unique(labels)) < 2:
        return -1

    score = silhouette_score(w2v_df, labels)
    return score

def objective_birch(trial):
    params = {
        'threshold': trial.suggest_float('threshold', 0.1, 2.0),
        'branching_factor': trial.suggest_int('branching_factor', 10, 100)
    }

    model = Birch(**params).fit(labse_df)

    labels = model.labels_
    if len(np.unique(labels)) < 2:
        return -1

    score = silhouette_score(labse_df, labels)
    return score

# %%
studies = {}

# %%
studies['kmeans'] = optuna.create_study(direction='maximize')
studies['kmeans'].optimize(objective_kmeans, n_trials=50)
studies['kmeans'].best_params
# Out:
# [I 2025-03-12 10:20:24,960] A new study created in memory with name: no-name-55319dfd-88e6-418d-a746-fce845b8dd03
# <ipython-input-29-9fb875e6b6d0>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# [I 2025-03-12 10:20:44,543] Trial 0 finished with value: 0.38599498177553776 and parameters: {'n_init': 17, 'max_iter': 599, 'tol': 0.011031794114396254, 'algorithm': 'elkan'}. Best is trial 0 with value: 0.38599498177553776.
# <ipython-input-29-9fb875e6b6d0>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# [I 2025-03-12 10:20:58,457] Trial 1 finished with value: 0.3773783692817349 and parameters: {'n_init': 18, 'max_iter': 904, 'tol': 0.06096852081168341, 'algorithm': 'lloyd'}. Best is trial 0 with value: 0.38599498177553776.
# <ipython-input-29-9fb875e6b6d0>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# [I 2025-03-12 10:21:10,287] Trial 2 finished with value: 0.36505844679519317 and parameters: {'n_init': 10, 'max_iter': 241, 'tol': 0.057248733689589694, 'algorithm': 'lloyd'}. Best is trial 0 with value: 0.38599498177553776.
# <ipython-input-29-9fb875e6b6d0>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# [I 2025-03-12 10:21:28,785] Trial 3 finished with value: 0.3863429826668481 and parameters: {'n_init': 13, 'max_iter': 971, 'tol': 1.925666009663008e-05, 'algorithm': 'elkan'}. Best is trial 3 with value: 0.3863429826668481.
# <ipython-input-29-9fb875e6b6d0>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# [I 2025-03-12 10:21:41,908] Trial 4 finished with value: 0.36111876654858116 and parameters: {'n_init': 7, 'max_iter': 114, 'tol': 2.7936466568564428e-05, 'algorithm': 'elkan'}. Best is trial 3 with value: 0.3863429826668481.
# <ipython-input-29-9fb875e6b6d0>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# [I 2025-03-12 10:21:56,741] Trial 5 finished with value: 0.3641822480790003 and parameters: {'n_init': 13, 'max_iter': 702, 'tol': 6.13570878394711e-05, 'algorithm': 'lloyd'}. Best is trial 3 with value: 0.3863429826668481.
# <ipython-input-29-9fb875e6b6d0>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# [I 2025-03-12 10:22:14,061] Trial 6 finished with value: 0.37847734815181544 and parameters: {'n_init': 20, 'max_iter': 264, 'tol': 0.0005210126079031615, 'algorithm': 'elkan'}. Best is trial 3 with value: 0.3863429826668481.
# <ipython-input-29-9fb875e6b6d0>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# [I 2025-03-12 10:22:27,780] Trial 7 finished with value: 0.37644617264607355 and parameters: {'n_init': 10, 'max_iter': 210, 'tol': 0.0002084411027591079, 'algorithm': 'elkan'}. Best is trial 3 with value: 0.3863429826668481.
# <ipython-input-29-9fb875e6b6d0>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# [I 2025-03-12 10:22:41,546] Trial 8 finished with value: 0.36932836069423514 and parameters: {'n_init': 11, 'max_iter': 992, 'tol': 0.00043054833811307676, 'algorithm': 'lloyd'}. Best is trial 3 with value: 0.3863429826668481.
# <ipython-input-29-9fb875e6b6d0>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# [I 2025-03-12 10:22:55,219] Trial 9 finished with value: 0.37151776343811016 and parameters: {'n_init': 11, 'max_iter': 571, 'tol': 0.010785187709773093, 'algorithm': 'elkan'}. Best is trial 3 with value: 0.3863429826668481.
# <ipython-input-29-9fb875e6b6d0>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# [I 2025-03-12 10:23:07,909] Trial 10 finished with value: 0.36078255053140934 and parameters: {'n_init': 5, 'max_iter': 809, 'tol': 1.0113035005550434e-05, 'algorithm': 'elkan'}. Best is trial 3 with value: 0.3863429826668481.
# <ipython-input-29-9fb875e6b6d0>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# [I 2025-03-12 10:23:22,395] Trial 11 finished with value: 0.35488855535732394 and parameters: {'n_init': 15, 'max_iter': 484, 'tol': 0.004153724612565762, 'algorithm': 'elkan'}. Best is trial 3 with value: 0.3863429826668481.
# <ipython-input-29-9fb875e6b6d0>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# [I 2025-03-12 10:23:37,641] Trial 12 finished with value: 0.37583103075285157 and parameters: {'n_init': 16, 'max_iter': 428, 'tol': 0.0038497328484691884, 'algorithm': 'elkan'}. Best is trial 3 with value: 0.3863429826668481.
# <ipython-input-29-9fb875e6b6d0>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# [I 2025-03-12 10:23:59,009] Trial 13 finished with value: 0.37882988919811644 and parameters: {'n_init': 15, 'max_iter': 686, 'tol': 0.012708347524630808, 'algorithm': 'elkan'}. Best is trial 3 with value: 0.3863429826668481.
# <ipython-input-29-9fb875e6b6d0>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# [I 2025-03-12 10:24:18,103] Trial 14 finished with value: 0.37432959799560717 and parameters: {'n_init': 18, 'max_iter': 733, 'tol': 0.002100130461530342, 'algorithm': 'elkan'}. Best is trial 3 with value: 0.3863429826668481.
# <ipython-input-29-9fb875e6b6d0>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# [I 2025-03-12 10
 'algorithm': 'lloyd'}. Best is trial 3 with value: 0.3863429826668481.
# <ipython-input-29-9fb875e6b6d0>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# [I 2025-03-12 10:30:01,553] Trial 37 finished with value: 0.38079048971487006 and parameters: {'n_init': 20, 'max_iter': 817, 'tol': 4.2241566931372525e-05, 'algorithm': 'lloyd'}. Best is trial 3 with value: 0.3863429826668481.
# <ipython-input-29-9fb875e6b6d0>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# [I 2025-03-12 10:30:18,034] Trial 38 finished with value: 0.37245318138979383 and parameters: {'n_init': 20, 'max_iter': 948, 'tol': 4.909491675568945e-05, 'algorithm': 'lloyd'}. Best is trial 3 with value: 0.3863429826668481.
# <ipython-input-29-9fb875e6b6d0>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# [I 2025-03-12 10:30:31,146] Trial 39 finished with value: 0.369729711522273 and parameters: {'n_init': 8, 'max_iter': 814, 'tol': 2.772464427107753e-05, 'algorithm': 'lloyd'}. Best is trial 3 with value: 0.3863429826668481.
# <ipython-input-29-9fb875e6b6d0>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# [I 2025-03-12 10:30:46,375] Trial 40 finished with value: 0.3828835463947287 and parameters: {'n_init': 20, 'max_iter': 901, 'tol': 0.00029024443310263535, 'algorithm': 'lloyd'}. Best is trial 3 with value: 0.3863429826668481.
# <ipython-input-29-9fb875e6b6d0>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# [I 2025-03-12 10:31:02,108] Trial 41 finished with value: 0.35586875747287583 and parameters: {'n_init': 20, 'max_iter': 898, 'tol': 0.0003037406544054954, 'algorithm': 'lloyd'}. Best is trial 3 with value: 0.3863429826668481.
# <ipython-input-29-9fb875e6b6d0>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# [I 2025-03-12 10:31:18,645] Trial 42 finished with value: 0.3842180799150107 and parameters: {'n_init': 20, 'max_iter': 837, 'tol': 6.333114333486476e-05, 'algorithm': 'lloyd'}. Best is trial 3 with value: 0.3863429826668481.
# <ipython-input-29-9fb875e6b6d0>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# [I 2025-03-12 10:31:34,569] Trial 43 finished with value: 0.3694189444188551 and parameters: {'n_init': 19, 'max_iter': 952, 'tol': 8.902829979208005e-05, 'algorithm': 'lloyd'}. Best is trial 3 with value: 0.3863429826668481.
# <ipython-input-29-9fb875e6b6d0>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# [I 2025-03-12 10:31:51,998] Trial 44 finished with value: 0.385873688114949 and parameters: {'n_init': 18, 'max_iter': 999, 'tol': 1.5328765017752634e-05, 'algorithm': 'lloyd'}. Best is trial 3 with value: 0.3863429826668481.
# <ipython-input-29-9fb875e6b6d0>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# [I 2025-03-12 10:32:07,400] Trial 45 finished with value: 0.3775079646326476 and parameters: {'n_init': 18, 'max_iter': 1000, 'tol': 1.866329912105195e-05, 'algorithm': 'lloyd'}. Best is trial 3 with value: 0.3863429826668481.
# <ipython-input-29-9fb875e6b6d0>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# [I 2025-03-12 10:32:23,315] Trial 46 finished with value: 0.38243409028798814 and parameters: {'n_init': 17, 'max_iter': 859, 'tol': 8.751349632056458e-05, 'algorithm': 'lloyd'}. Best is trial 3 with value: 0.3863429826668481.
# <ipython-input-29-9fb875e6b6d0>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# [I 2025-03-12 10:32:35,624] Trial 47 finished with value: 0.37582396964372894 and parameters: {'n_init': 5, 'max_iter': 759, 'tol': 0.00015127050308653275, 'algorithm': 'lloyd'}. Best is trial 3 with value: 0.3863429826668481.
# <ipython-input-29-9fb875e6b6d0>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# [I 2025-03-12 10:32:51,249] Trial 48 finished with value: 0.3785216542793938 and parameters: {'n_init': 18, 'max_iter': 141, 'tol': 1.734229570443979e-05, 'algorithm': 'lloyd'}. Best is trial 3 with value: 0.3863429826668481.
# <ipython-input-29-9fb875e6b6d0>:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# [I 2025-03-12 10:33:04,440] Trial 49 finished with value: 0.38507622526155283 and parameters: {'n_init': 9, 'max_iter': 294, 'tol': 3.593076628004209e-05, 'algorithm': 'lloyd'}. Best is trial 3 with value: 0.3863429826668481.
# {'n_init': 13,
#  'max_iter': 971,
#  'tol': 1.925666009663008e-05,
#  'algorithm': 'elkan'}

# %%
with open(output_path+'optuna_studies', "wb") as output_file:
  pickle.dump(studies, output_file)

# %%
studies['gmm'] = optuna.create_study(direction='maximize')
studies['gmm'].optimize(objective_gmm, n_trials=50)
studies['gmm'].best_params
# Out:
# [I 2025-03-12 10:33:25,455] A new study created in memory with name: no-name-2cc7d256-10ad-418f-9fab-622ce51d34a0
# <ipython-input-29-9fb875e6b6d0>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# <ipython-input-29-9fb875e6b6d0>:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_covar': trial.suggest_loguniform('reg_covar', 1e-6, 1e-2),
# [I 2025-03-12 10:33:39,501] Trial 0 finished with value: -0.08851842924952211 and parameters: {'covariance_type': 'tied', 'tol': 0.029004351646049753, 'reg_covar': 6.354130112411323e-05, 'init_params': 'random'}. Best is trial 0 with value: -0.08851842924952211.
# <ipython-input-29-9fb875e6b6d0>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# <ipython-input-29-9fb875e6b6d0>:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_covar': trial.suggest_loguniform('reg_covar', 1e-6, 1e-2),
# [I 2025-03-12 10:33:53,952] Trial 1 finished with value: 0.3654394556093609 and parameters: {'covariance_type': 'diag', 'tol': 1.9483125104915298e-05, 'reg_covar': 3.902765227981644e-05, 'init_params': 'kmeans'}. Best is trial 1 with value: 0.3654394556093609.
# <ipython-input-29-9fb875e6b6d0>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# <ipython-input-29-9fb875e6b6d0>:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_covar': trial.suggest_loguniform('reg_covar', 1e-6, 1e-2),
# [I 2025-03-12 10:34:27,117] Trial 2 finished with value: 0.3143812027190895 and parameters: {'covariance_type': 'tied', 'tol': 5.787811269508591e-05, 'reg_covar': 0.0018722094408935644, 'init_params': 'kmeans'}. Best is trial 1 with value: 0.3654394556093609.
# <ipython-input-29-9fb875e6b6d0>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# <ipython-input-29-9fb875e6b6d0>:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_covar': trial.suggest_loguniform('reg_covar', 1e-6, 1e-2),
# [I 2025-03-12 10
 'init_params': 'kmeans'}. Best is trial 14 with value: 0.38640928830068966.
# <ipython-input-29-9fb875e6b6d0>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# <ipython-input-29-9fb875e6b6d0>:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_covar': trial.suggest_loguniform('reg_covar', 1e-6, 1e-2),
# [I 2025-03-12 10:44:24,829] Trial 37 finished with value: 0.30730721931874216 and parameters: {'covariance_type': 'diag', 'tol': 3.361384279340128e-05, 'reg_covar': 0.00024452349770847823, 'init_params': 'random'}. Best is trial 14 with value: 0.38640928830068966.
# <ipython-input-29-9fb875e6b6d0>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# <ipython-input-29-9fb875e6b6d0>:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_covar': trial.suggest_loguniform('reg_covar', 1e-6, 1e-2),
# [I 2025-03-12 10:44:54,347] Trial 38 finished with value: 0.3526346234527234 and parameters: {'covariance_type': 'full', 'tol': 0.0019819784665300977, 'reg_covar': 0.001035894688998803, 'init_params': 'kmeans'}. Best is trial 14 with value: 0.38640928830068966.
# <ipython-input-29-9fb875e6b6d0>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# <ipython-input-29-9fb875e6b6d0>:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_covar': trial.suggest_loguniform('reg_covar', 1e-6, 1e-2),
# [I 2025-03-12 10:45:08,522] Trial 39 finished with value: 0.2719871590888911 and parameters: {'covariance_type': 'diag', 'tol': 9.233017701851851e-05, 'reg_covar': 7.385967862323592e-05, 'init_params': 'random'}. Best is trial 14 with value: 0.38640928830068966.
# <ipython-input-29-9fb875e6b6d0>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# <ipython-input-29-9fb875e6b6d0>:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_covar': trial.suggest_loguniform('reg_covar', 1e-6, 1e-2),
# [I 2025-03-12 10:45:26,647] Trial 40 finished with value: 0.2879395771043842 and parameters: {'covariance_type': 'tied', 'tol': 0.005770692206853974, 'reg_covar': 3.855274679091294e-05, 'init_params': 'kmeans'}. Best is trial 14 with value: 0.38640928830068966.
# <ipython-input-29-9fb875e6b6d0>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# <ipython-input-29-9fb875e6b6d0>:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_covar': trial.suggest_loguniform('reg_covar', 1e-6, 1e-2),
# [I 2025-03-12 10:45:39,384] Trial 41 finished with value: 0.3726216468265233 and parameters: {'covariance_type': 'diag', 'tol': 1.7115365314441493e-05, 'reg_covar': 0.0033758605281146046, 'init_params': 'kmeans'}. Best is trial 14 with value: 0.38640928830068966.
# <ipython-input-29-9fb875e6b6d0>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# <ipython-input-29-9fb875e6b6d0>:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_covar': trial.suggest_loguniform('reg_covar', 1e-6, 1e-2),
# [I 2025-03-12 10:45:52,597] Trial 42 finished with value: 0.3677630162188777 and parameters: {'covariance_type': 'diag', 'tol': 4.409636216978493e-05, 'reg_covar': 0.0006009659288227018, 'init_params': 'kmeans'}. Best is trial 14 with value: 0.38640928830068966.
# <ipython-input-29-9fb875e6b6d0>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# <ipython-input-29-9fb875e6b6d0>:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_covar': trial.suggest_loguniform('reg_covar', 1e-6, 1e-2),
# [I 2025-03-12 10:46:07,177] Trial 43 finished with value: 0.3576462034949716 and parameters: {'covariance_type': 'diag', 'tol': 1.6383974003854518e-05, 'reg_covar': 0.0017528707105207801, 'init_params': 'kmeans'}. Best is trial 14 with value: 0.38640928830068966.
# <ipython-input-29-9fb875e6b6d0>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# <ipython-input-29-9fb875e6b6d0>:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_covar': trial.suggest_loguniform('reg_covar', 1e-6, 1e-2),
# [I 2025-03-12 10:46:20,730] Trial 44 finished with value: 0.3694368654284073 and parameters: {'covariance_type': 'diag', 'tol': 2.4980112489246245e-05, 'reg_covar': 0.00012326233802775554, 'init_params': 'kmeans'}. Best is trial 14 with value: 0.38640928830068966.
# <ipython-input-29-9fb875e6b6d0>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# <ipython-input-29-9fb875e6b6d0>:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_covar': trial.suggest_loguniform('reg_covar', 1e-6, 1e-2),
# [I 2025-03-12 10:46:35,083] Trial 45 finished with value: 0.35739257474404384 and parameters: {'covariance_type': 'diag', 'tol': 1.3417056360356009e-05, 'reg_covar': 0.00044753728384708263, 'init_params': 'kmeans'}. Best is trial 14 with value: 0.38640928830068966.
# <ipython-input-29-9fb875e6b6d0>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# <ipython-input-29-9fb875e6b6d0>:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_covar': trial.suggest_loguniform('reg_covar', 1e-6, 1e-2),
# [I 2025-03-12 10:46:49,169] Trial 46 finished with value: 0.3527079809797974 and parameters: {'covariance_type': 'spherical', 'tol': 4.22286543558741e-05, 'reg_covar': 0.0007114225249512542, 'init_params': 'kmeans'}. Best is trial 14 with value: 0.38640928830068966.
# <ipython-input-29-9fb875e6b6d0>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# <ipython-input-29-9fb875e6b6d0>:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_covar': trial.suggest_loguniform('reg_covar', 1e-6, 1e-2),
# [I 2025-03-12 10:47:01,575] Trial 47 finished with value: 0.36192576431180473 and parameters: {'covariance_type': 'diag', 'tol': 0.0002956336720022941, 'reg_covar': 0.006046627604399562, 'init_params': 'kmeans'}. Best is trial 14 with value: 0.38640928830068966.
# <ipython-input-29-9fb875e6b6d0>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# <ipython-input-29-9fb875e6b6d0>:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_covar': trial.suggest_loguniform('reg_covar', 1e-6, 1e-2),
# [I 2025-03-12 10:48:08,195] Trial 48 finished with value: 0.11851355437253529 and parameters: {'covariance_type': 'full', 'tol': 0.0024772933546355165, 'reg_covar': 5.722394323980309e-06, 'init_params': 'random'}. Best is trial 14 with value: 0.38640928830068966.
# <ipython-input-29-9fb875e6b6d0>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'tol': trial.suggest_loguniform('tol', 1e-5, 1e-1),
# <ipython-input-29-9fb875e6b6d0>:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_covar': trial.suggest_loguniform('reg_covar', 1e-6, 1e-2),
# [I 2025-03-12 10:48:22,416] Trial 49 finished with value: 0.3572662165554384 and parameters: {'covariance_type': 'diag', 'tol': 0.0008311515427599492, 'reg_covar': 0.0003256823382497618, 'init_params': 'kmeans'}. Best is trial 14 with value: 0.38640928830068966.
# {'covariance_type': 'diag',
#  'tol': 1.211052497963514e-05,
#  'reg_covar': 0.0005148318295957446,
#  'init_params': 'kmeans'}

# %%
with open(output_path+'optuna_studies', "wb") as output_file:
  pickle.dump(studies, output_file)

# %%
studies['agglomerative'] = optuna.create_study(direction='maximize')
studies['agglomerative'].optimize(objective_agglomerative, n_trials=50)
studies['agglomerative'].best_params
# Out:
finished with value: 0.3112786987765346 and parameters: {'metric': 'cosine', 'linkage': 'average'}. Best is trial 3 with value: 0.3112786987765346.
# [I 2025-03-12 13:06:48,699] Trial 45 finished with value: 0.2799174466350489 and parameters: {'metric': 'cosine', 'linkage': 'complete'}. Best is trial 3 with value: 0.3112786987765346.
# [I 2025-03-12 13:08:35,726] Trial 46 finished with value: 0.3112786987765346 and parameters: {'metric': 'cosine', 'linkage': 'average'}. Best is trial 3 with value: 0.3112786987765346.
# [I 2025-03-12 13:10:19,503] Trial 47 finished with value: 0.3112786987765346 and parameters: {'metric': 'cosine', 'linkage': 'average'}. Best is trial 3 with value: 0.3112786987765346.
# [I 2025-03-12 13:12:12,621] Trial 48 finished with value: 0.24592505185634173 and parameters: {'metric': 'manhattan', 'linkage': 'average'}. Best is trial 3 with value: 0.3112786987765346.
# [I 2025-03-12 13:14:01,766] Trial 49 finished with value: 0.2939252965662404 and parameters: {'metric': 'euclidean', 'linkage': 'average'}. Best is trial 3 with value: 0.3112786987765346.
# {'metric': 'cosine', 'linkage': 'average'}

# %%
with open(output_path+'optuna_studies', "wb") as output_file:
  pickle.dump(studies, output_file)

# %%
studies['meanshift'] = optuna.create_study(direction='maximize')
studies['meanshift'].optimize(objective_meanshift_2, n_trials=10)
studies['meanshift'].best_params
# Out:
# [I 2025-03-12 15:06:52,958] A new study created in memory with name: no-name-aaf470ef-d76c-4524-92cc-78aa47659980
# [I 2025-03-12 15:15:16,072] Trial 0 finished with value: 0.44666879860558373 and parameters: {'bandwidth': 2.291286897441325, 'bin_seeding': False, 'min_bin_freq': 10, 'max_iter': 219}. Best is trial 0 with value: 0.44666879860558373.
# [I 2025-03-12 15:24:02,156] Trial 1 finished with value: 0.4590100201663158 and parameters: {'bandwidth': 2.3671066028753565, 'bin_seeding': False, 'min_bin_freq': 6, 'max_iter': 280}. Best is trial 1 with value: 0.4590100201663158.
# [I 2025-03-12 15:32:46,953] Trial 2 finished with value: 0.4590100201663158 and parameters: {'bandwidth': 2.3804431803674535, 'bin_seeding': False, 'min_bin_freq': 4, 'max_iter': 260}. Best is trial 1 with value: 0.4590100201663158.
# [I 2025-03-12 15:41:57,199] Trial 3 finished with value: 0.4770119105722241 and parameters: {'bandwidth': 2.1249219390087783, 'bin_seeding': False, 'min_bin_freq': 9, 'max_iter': 249}. Best is trial 3 with value: 0.4770119105722241.
# [I 2025-03-12 15:50:27,414] Trial 4 finished with value: -1.0 and parameters: {'bandwidth': 2.4197462360790234, 'bin_seeding': False, 'min_bin_freq': 2, 'max_iter': 368}. Best is trial 3 with value: 0.4770119105722241.
# [I 2025-03-12 15:58:53,841] Trial 5 finished with value: 0.4548445556043601 and parameters: {'bandwidth': 2.3080911632680823, 'bin_seeding': False, 'min_bin_freq': 7, 'max_iter': 340}. Best is trial 3 with value: 0.4770119105722241.
# [I 2025-03-12 16:07:15,184] Trial 6 finished with value: 0.44671095466258526 and parameters: {'bandwidth': 2.288508844510223, 'bin_seeding': False, 'min_bin_freq': 2, 'max_iter': 362}. Best is trial 3 with value: 0.4770119105722241.
# [I 2025-03-12 16:15:44,895] Trial 7 finished with value: 0.45458200851788483 and parameters: {'bandwidth': 2.3176379351604353, 'bin_seeding': False, 'min_bin_freq': 9, 'max_iter': 202}. Best is trial 3 with value: 0.4770119105722241.
# [I 2025-03-12 16:24:23,141] Trial 8 finished with value: 0.4714191492474115 and parameters: {'bandwidth': 2.1645009260239063, 'bin_seeding': False, 'min_bin_freq': 8, 'max_iter': 320}. Best is trial 3 with value: 0.4770119105722241.
# [I 2025-03-12 16:33:11,066] Trial 9 finished with value: 0.457174173094066 and parameters: {'bandwidth': 2.2598738880274998, 'bin_seeding': False, 'min_bin_freq': 1, 'max_iter': 222}. Best is trial 3 with value: 0.4770119105722241.
# {'bandwidth': 2.1249219390087783,
#  'bin_seeding': False,
#  'min_bin_freq': 9,
#  'max_iter': 249}

# %%
with open(output_path+'optuna_studies', "wb") as output_file:
  pickle.dump(studies, output_file)

# %%
studies['birch'] = optuna.create_study(direction='maximize')
studies['birch'].optimize(objective_birch, n_trials=20)
studies['birch'].best_params
# Out:
# [I 2025-03-12 16:33:35,715] A new study created in memory with name: no-name-ab48ade5-f373-41d2-acfc-061de86dba6f
# [I 2025-03-12 16:33:48,841] Trial 0 finished with value: 0.6783183544792459 and parameters: {'threshold': 1.7317802228251986, 'branching_factor': 84}. Best is trial 0 with value: 0.6783183544792459.
# [I 2025-03-12 16:34:02,085] Trial 1 finished with value: 0.6783183544792459 and parameters: {'threshold': 1.6499477291557532, 'branching_factor': 96}. Best is trial 0 with value: 0.6783183544792459.
# [I 2025-03-12 16:34:15,511] Trial 2 finished with value: 0.6783183544792459 and parameters: {'threshold': 1.5751082187651952, 'branching_factor': 20}. Best is trial 0 with value: 0.6783183544792459.
# [I 2025-03-12 16:34:28,092] Trial 3 finished with value: 0.29297458017745465 and parameters: {'threshold': 0.503683461681595, 'branching_factor': 60}. Best is trial 0 with value: 0.6783183544792459.
# [I 2025-03-12 16:34:40,926] Trial 4 finished with value: 0.6783183544792459 and parameters: {'threshold': 1.4490173705779896, 'branching_factor': 58}. Best is trial 0 with value: 0.6783183544792459.
# [I 2025-03-12 16:34:53,925] Trial 5 finished with value: 0.6783183544792459 and parameters: {'threshold': 1.8700960834152254, 'branching_factor': 85}. Best is trial 0 with value: 0.6783183544792459.
# [I 2025-03-12 16:35:06,144] Trial 6 finished with value: 0.2629766200976968 and parameters: {'threshold': 0.391363549923755, 'branching_factor': 81}. Best is trial 0 with value: 0.6783183544792459.
# [I 2025-03-12 16:35:20,139] Trial 7 finished with value: 0.27942995787992037 and parameters: {'threshold': 0.2007498666143119, 'branching_factor': 85}. Best is trial 0 with value: 0.6783183544792459.
# [I 2025-03-12 16:35:33,334] Trial 8 finished with value: 0.3328126245273584 and parameters: {'threshold': 0.7364601520672864, 'branching_factor': 87}. Best is trial 0 with value: 0.6783183544792459.
# [I 2025-03-12 16:35:46,134] Trial 9 finished with value: 0.2642425971938542 and parameters: {'threshold': 1.2032232039243664, 'branching_factor': 18}. Best is trial 0 with value: 0.6783183544792459.
# [I 2025-03-12 16:35:59,408] Trial 10 finished with value: 0.67656482658658 and parameters: {'threshold': 1.956830562232156, 'branching_factor': 36}. Best is trial 0 with value: 0.6783183544792459.
# [I 2025-03-12 16:36:12,546] Trial 11 finished with value: 0.6783183544792459 and parameters: {'threshold': 1.5590845129581408, 'branching_factor': 100}. Best is trial 0 with value: 0.6783183544792459.
# [I 2025-03-12 16:36:25,597] Trial 12 finished with value: 0.6783183544792459 and parameters: {'threshold': 1.1335318150471292, 'branching_factor': 100}. Best is trial 0 with value: 0.6783183544792459.
# [I 2025-03-12 16:36:38,640] Trial 13 finished with value: 0.6783183544792459 and parameters: {'threshold': 1.7592158929993083, 'branching_factor': 70}. Best is trial 0 with value: 0.6783183544792459.
# [I 2025-03-12 16:36:51,622] Trial 14 finished with value: 0.6783183544792459 and parameters: {'threshold': 1.299952053791715, 'branching_factor': 42}. Best is trial 0 with value: 0.6783183544792459.
# [I 2025-03-12 16:37:04,759] Trial 15 finished with value: 0.6783183544792459 and parameters: {'threshold': 1.7203731416289023, 'branching_factor': 72}. Best is trial 0 with value: 0.6783183544792459.
# [I 2025-03-12 16:37:16,946] Trial 16 finished with value: 0.303204532541167 and parameters: {'threshold': 0.8733751775882574, 'branching_factor': 94}. Best is trial 0 with value: 0.6783183544792459.
# [I 2025-03-12 16:37:29,800] Trial 17 finished with value: 0.6783183544792459 and parameters: {'threshold': 1.3521584542884353, 'branching_factor': 72}. Best is trial 0 with value: 0.6783183544792459.
# [I 2025-03-12 16:37:41,889] Trial 18 finished with value: 0.30083103439352904 and parameters: {'threshold': 1.0151983651451644, 'branching_factor': 45}. Best is trial 0 with value: 0.6783183544792459.
# [I 2025-03-12 16:37:54,997] Trial 19 finished with value: 0.67656482658658 and parameters: {'threshold': 1.978646586731541, 'branching_factor': 66}. Best is trial 0 with value: 0.6783183544792459.
# {'threshold': 1.7317802228251986, 'branching_factor': 84}

# %%
with open(output_path+'optuna_studies', "wb") as output_file:
  pickle.dump(studies, output_file)

# %%
studies.keys()
# Out:
# dict_keys(['kmeans', 'gmm', 'agglomerative', 'meanshift', 'birch'])

# %% [markdown]
# # Clustering Model Training With Best Parameters

# %%
studies_path = output_path + 'optuna_studies'
with open(studies_path, "rb") as input_file:
  studies = pickle.load(input_file)

# %%
kmeans_model = KMeans(n_clusters=N_CLUSTERS, **studies['kmeans'].best_params).fit(labse_df)

with open(output_path+"kmeans_model.pkl", "wb") as f:
    pickle.dump(kmeans_model, f)

# %%
gmm_model = GaussianMixture(n_components=N_CLUSTERS, **studies['gmm'].best_params).fit(labse_df)

with open(output_path+"gmm_model.pkl", "wb") as f:
    pickle.dump(gmm_model, f)

# %%
agg_model = AgglomerativeClustering(n_clusters=N_CLUSTERS, **studies['agglomerative'].best_params).fit(labse_df)

with open(output_path+"agg_model.pkl", "wb") as f:
    pickle.dump(agg_model, f)

# %%
ms_model = MeanShift(**studies['meanshift'].best_params).fit(w2v_df)

with open(output_path+"ms_model.pkl", "wb") as f:
    pickle.dump(ms_model, f)

# %%
birch_model = Birch(**studies['birch'].best_params).fit(labse_df)

with open(output_path+"birch_model.pkl", "wb") as f:
    pickle.dump(birch_model, f)

# %% [markdown]
# # Result Analysis

# %%
with open(output_path+"kmeans_model.pkl", "rb") as f:
  kmeans = pickle.load(f)

with open(output_path+"gmm_model.pkl", "rb") as f:
  gmm = pickle.load(f)

with open(output_path+"agg_model.pkl", "rb") as f:
  agg = pickle.load(f)

with open(output_path+"ms_model.pkl", "rb") as f:
  ms = pickle.load(f)

with open(output_path+"birch_model.pkl", "rb") as f:
  birch = pickle.load(f)

# %%
tsne = TSNE(n_components=2, random_state=42)
labse_tsne = tsne.fit_transform(labse_df)

tsne = TSNE(n_components=2, random_state=42)
w2v_tsne = tsne.fit_transform(w2v_df)

# %% [markdown]
# ## KMeans

# %%
labels = kmeans.labels_

print("Silhouette Score (KMeans):", silhouette_score(labse_df, labels))
print("Davies-Bouldin Index (KMeans):", davies_bouldin_score(labse_df, labels))
print("Calinski-Harabasz Index (KMeans):", calinski_harabasz_score(labse_df, labels))
print("Adjusted Rand Index (KMeans vs. True Labels):", adjusted_rand_score(y_true, labels))
print("Normalized Mutual Information (KMeans vs. True Labels):", normalized_mutual_info_score(y_true, labels))
# Out:
# Silhouette Score (KMeans): 0.3749060399982156
# Davies-Bouldin Index (KMeans): 0.7110252657891654
# Calinski-Harabasz Index (KMeans): 9847.181569599905
# Adjusted Rand Index (KMeans vs. True Labels): 0.1614630118200193
# Normalized Mutual Information (KMeans vs. True Labels): 0.3364386434762212

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.scatterplot(x=labse_tsne[:, 0], y=labse_tsne[:, 1], hue=labels, palette='viridis')
# Out:
# <Axes: >

# %% [markdown]
# ## Gaussian Mixture Model

# %%
labels = gmm.predict(labse_df)

print("Silhouette Score (GMM):", silhouette_score(labse_df, labels))
print("Davies-Bouldin Index (GMM):", davies_bouldin_score(labse_df, labels))
print("Calinski-Harabasz Index (GMM):", calinski_harabasz_score(labse_df, labels))
print("Adjusted Rand Index (GMM vs. True Labels):", adjusted_rand_score(y_true, labels))
print("Normalized Mutual Information (GMM vs. True Labels):", normalized_mutual_info_score(y_true, labels))
# Out:
# Silhouette Score (GMM): 0.35743536046542573
# Davies-Bouldin Index (GMM): 0.8600966385884629
# Calinski-Harabasz Index (GMM): 8024.157528223845
# Adjusted Rand Index (GMM vs. True Labels): 0.15481570903451844
# Normalized Mutual Information (GMM vs. True Labels): 0.3383701066966498

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.scatterplot(x=labse_tsne[:, 0], y=labse_tsne[:, 1], hue=labels, palette='viridis')
# Out:
# <Axes: >

# %% [markdown]
# ## Agglomerative clustering

# %%
labels = agg.labels_

print("Silhouette Score (AGG):", silhouette_score(labse_df, labels))
print("Davies-Bouldin Index (AGG):", davies_bouldin_score(labse_df, labels))
print("Calinski-Harabasz Index (AGG):", calinski_harabasz_score(labse_df, labels))
print("Adjusted Rand Index (AGG vs. True Labels):", adjusted_rand_score(y_true, labels))
print("Normalized Mutual Information (AGG vs. True Labels):", normalized_mutual_info_score(y_true, labels))
# Out:
# Silhouette Score (AGG): 0.3112786987765346
# Davies-Bouldin Index (AGG): 0.4234989467845218
# Calinski-Harabasz Index (AGG): 3216.4803083958936
# Adjusted Rand Index (AGG vs. True Labels): 0.11310696506063213
# Normalized Mutual Information (AGG vs. True Labels): 0.25583526648730553

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.scatterplot(x=labse_tsne[:, 0], y=labse_tsne[:, 1], hue=labels, palette='viridis')
# Out:
# <Axes: >

# %%
linked = linkage(labse_df, method='average')
plt.figure(figsize=(10, 5))
dendrogram(linked)
#plt.title('Dendrogram (Hierarchical Clustering)')
plt.show()

# %% [markdown]
# ## MeanShift

# %%
labels = ms.labels_

print("Silhouette Score (MeanShift):", silhouette_score(w2v_df, labels))
print("Davies-Bouldin Index (MeanShift):", davies_bouldin_score(w2v_df, labels))
print("Calinski-Harabasz Index (MeanShift):", calinski_harabasz_score(w2v_df, labels))
print("Adjusted Rand Index (MeanShift vs. True Labels):", adjusted_rand_score(y_true, labels))
print("Normalized Mutual Information (MeanShift vs. True Labels):", normalized_mutual_info_score(y_true, labels))
# Out:
# Silhouette Score (MeanShift): 0.4770119105722241
# Davies-Bouldin Index (MeanShift): 0.6638993924319253
# Calinski-Harabasz Index (MeanShift): 3272.257625199711
# Adjusted Rand Index (MeanShift vs. True Labels): 0.012649487623165792
# Normalized Mutual Information (MeanShift vs. True Labels): 0.0647097104469459

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.scatterplot(x=w2v_tsne[:, 0], y=w2v_tsne[:, 1], hue=labels, palette='viridis')
# Out:
# <Axes: >

# %%
meanshift_centroids = ms.cluster_centers_
linked_meanshift = linkage(meanshift_centroids, method='ward')

plt.figure(figsize=(10, 5))
dendrogram(linked_meanshift)
plt.show()

# %% [markdown]
# ## BIRCH

# %%
labels = birch.labels_

print("Silhouette Score (BIRCH):", silhouette_score(labse_df, labels))
print("Davies-Bouldin Index (BIRCH):", davies_bouldin_score(labse_df, labels))
print("Calinski-Harabasz Index (BIRCH):", calinski_harabasz_score(labse_df, labels))
print("Adjusted Rand Index (BIRCH vs. True Labels):", adjusted_rand_score(y_true, labels))
print("Normalized Mutual Information (BIRCH vs. True Labels):", normalized_mutual_info_score(y_true, labels))
# Out:
# Silhouette Score (BIRCH): 0.6783183544792459
# Davies-Bouldin Index (BIRCH): 0.9414463788122305
# Calinski-Harabasz Index (BIRCH): 396.14242496630305
# Adjusted Rand Index (BIRCH vs. True Labels): 0.0007752681806084852
# Normalized Mutual Information (BIRCH vs. True Labels): 0.004514501709957273

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.scatterplot(x=labse_tsne[:, 0], y=labse_tsne[:, 1], hue=labels, palette='viridis')
# Out:
# <Axes: >

# %%
birch_centroids = birch.subcluster_centers_
linked_birch = linkage(birch_centroids, method='ward')

plt.figure(figsize=(10, 5))
dendrogram(linked_birch)
plt.show()

# %% [markdown]
# ## Inner Cluster Predictions

# %%
res_df['kmeans'] = kmeans.labels_
res_df['gmm'] = gmm.predict(labse_df)
res_df['agg'] = agg.labels_
res_df['meanshift'] = ms.labels_
res_df['birch'] = birch.labels_
# Out:
# <ipython-input-61-14d28ea65831>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['kmeans'] = kmeans.labels_
# <ipython-input-61-14d28ea65831>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['gmm'] = gmm.predict(labse_df)
# <ipython-input-61-14d28ea65831>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['agg'] = agg.labels_
# <ipython-input-61-14d28ea65831>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['meanshift'] = ms.labels_
# <ipython-input-61-14d28ea65831>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res_df['birch'] = birch.labels_

# %%
res_df.to_csv(output_path+'res_df.csv', index=False)

# %%
def clustering_distributions(cluster_column):
  contingency_table = pd.crosstab(res_df[cluster_column], res_df["gr_stat_letter"])

  # Plot a heatmap
  plt.figure(figsize=(15, 8))
  sns.heatmap(contingency_table, annot=True, fmt="d", cmap="Blues")
  plt.title(f"Distribution of gr_stat_letter in {cluster_column} Clusters")
  plt.xlabel("gr_stat_letter")
  plt.ylabel("Cluster")
  plt.show()

  # Identify pure clusters
  pure_clusters = (contingency_table.max(axis=1) / contingency_table.sum(axis=1)) > 0.9  # 90% purity threshold
  pure_clusters = pure_clusters[pure_clusters].index.tolist()

  print(f"Pure clusters (90% threshold): {pure_clusters}")


def proportion_distribution(cluster_column):
  # Create a contingency table (counts)
  contingency_table = pd.crosstab(res_df[cluster_column], res_df["gr_stat_letter"])

  # Normalize the table to get proportions
  contingency_table_normalized = contingency_table.div(contingency_table.sum(axis=1), axis=0)

  # Plot stacked bar chart
  contingency_table_normalized.plot(kind='bar', stacked=True, figsize=(10,6), colormap='tab20')

  plt.title(f"Proportion of gr_stat_letter in {cluster_column} Clusters")
  plt.xlabel("Cluster")
  plt.ylabel("Proportion")
  plt.legend(title="gr_stat_letter", bbox_to_anchor=(1.05, 1), loc='upper left')
  plt.show()

# %%
clustering_distributions('kmeans')
# Out:
# Pure clusters (90% threshold): [8, 16, 17, 18]

# %%
proportion_distribution('kmeans')

# %%
clustering_distributions('gmm')
# Out:
# Pure clusters (90% threshold): [12, 15, 18]

# %%
proportion_distribution('gmm')

# %%
clustering_distributions('agg')
# Out:
# Pure clusters (90% threshold): [5, 12, 14, 15]

# %%
proportion_distribution('agg')

# %%
clustering_distributions('meanshift')
# Out:
# Pure clusters (90% threshold): [2]

# %%
proportion_distribution('meanshift')

# %%
clustering_distributions('birch')
# Out:
# Pure clusters (90% threshold): [1]

# %%
proportion_distribution('birch')
